# %% [markdown]
# # Online data
#
#
# ## References:
#
#
# - [k-rns.github](https://k-rns.github.io/workshop_data_reuse/)

# %% [markdown]
# ## Download dataset

# %%
#import urllib.request
#import pandas as pd


## .csv generated from: https://erddap.bco-dmo.org/erddap/tabledap/bcodmo_dataset_3937.html
#url = "https://erddap.bco-dmo.org/erddap/tabledap/bcodmo_dataset_3937.csv?cruise_name%2Cstation%2Ccast%2Ctime%2CYear%2CMonth%2CDay%2Ctimeutc%2Clongitude%2Clatitude%2Cdepth_max%2Cpres_max%2CDate%2Ctimecode%2CHOT_summary_file_name%2Cparameters%2Cnum_bottles%2Csection%2Cnav_code%2Cdepth_hgt%2CEXPOCODE%2CShip%2Ccomments%2CCTDPRS%2CCTDTMP%2CCTDSAL%2CCTDOXY%2CXMISS%2CCHLPIG%2CNUMBER%2CNITRATE%2CFLUOR%2CQUALT1"
#file_name = "bcodmo_dataset_3773.csv"
#urllib.request.urlretrieve(url, file_name)

# %% [markdown]
# ##  Online Dataset
#
# - Requirement: `conda install erddapy`

# %%
from erddapy import ERDDAP

e = ERDDAP(
    server= "https://erddap.bco-dmo.org/erddap/",
    protocol="tabledap",
    response="csv",
)

# %%
e.dataset_id = "bcodmo_dataset_3773"

# %%
# Print the URL - check
url = e.get_download_url()
print(url)
# Out:
# https://erddap.bco-dmo.org/erddap/tabledap/bcodmo_dataset_3773.csv?

# %%
df = e.to_pandas(index_col="time (UTC)",parse_dates=True)

# %%
df.head()
# Out:
#                            cruise_name (unitless) EXPOCODE (unitless)
# time (UTC)
# 1988-10-31 00:56:00+00:00                       1           32MW001_1  \
# 1988-10-31 00:56:00+00:00                       1           32MW001_1
# 1988-10-31 00:56:00+00:00                       1           32MW001_1
# 1988-10-31 00:56:00+00:00                       1           32MW001_1
# 1988-10-31 00:56:00+00:00                       1           32MW001_1
#
#                           Ship (unitless)  STNNBR (unitless)
# time (UTC)
# 1988-10-31 00:56:00+00:00       32MW001/1                  2  \
# 1988-10-31 00:56:00+00:00       32MW001/1                  2
# 1988-10-31 00:56:00+00:00       32MW001/1                  2
# 1988-10-31 00:56:00+00:00       32MW001/1                  2
# 1988-10-31 00:56:00+00:00       32MW001/1                  2
#
#                            CASTNO (unitless) section (unitless)
# time (UTC)
# 1988-10-31 00:56:00+00:00                  3               PRS2  \
# 1988-10-31 00:56:00+00:00                  3               PRS2
# 1988-10-31 00:56:00+00:00                  3               PRS2
# 1988-10-31 00:56:00+00:00                  3               PRS2
# 1988-10-31 00:56:00+00:00                  3               PRS2
#
#                            Date (unitless)  Year (unitless)  Month (unitless)
# time (UTC)
# 1988-10-31 00:56:00+00:00           103188             1988                10  \
# 1988-10-31 00:56:00+00:00           103188             1988                10
# 1988-10-31 00:56:00+00:00           103188             1988                10
# 1988-10-31 00:56:00+00:00           103188             1988                10
# 1988-10-31 00:56:00+00:00           103188             1988                10
#
#                            Day (unitless)  ...  QUALT1 (unitless)
# time (UTC)                                 ...
# 1988-10-31 00:56:00+00:00              31  ...            2222999  \
# 1988-10-31 00:56:00+00:00              31  ...            2222999
# 1988-10-31 00:56:00+00:00              31  ...            2222999
# 1988-10-31 00:56:00+00:00              31  ...            2222999
# 1988-10-31 00:56:00+00:00              31  ...            2222999
#
#                           QUALT2 (unitless)  QUALT3 (unitless)
# time (UTC)
# 1988-10-31 00:56:00+00:00           9222999            9999999  \
# 1988-10-31 00:56:00+00:00           9222999            9999999
# 1988-10-31 00:56:00+00:00           9222999            9999999
# 1988-10-31 00:56:00+00:00           9222999            9999999
# 1988-10-31 00:56:00+00:00           9222999            9999999
#
#                            QUALT4 (unitless) QUALT5 (unitless)
# time (UTC)
# 1988-10-31 00:56:00+00:00            9999999           9999999  \
# 1988-10-31 00:56:00+00:00            9999999           9999999
# 1988-10-31 00:56:00+00:00            9999999           9999999
# 1988-10-31 00:56:00+00:00            9999999           9999999
# 1988-10-31 00:56:00+00:00            9999999           9999999
#
#                            QUALT6 (unitless)  QUALT7 (unitless)
# time (UTC)
# 1988-10-31 00:56:00+00:00             999999             999999  \
# 1988-10-31 00:56:00+00:00             999999             999999
# 1988-10-31 00:56:00+00:00             999999             999999
# 1988-10-31 00:56:00+00:00             999999             999999
# 1988-10-31 00:56:00+00:00             999999             999999
#
#                            QUALT8 (unitless) QUALT9 (unitless)
# time (UTC)
# 1988-10-31 00:56:00+00:00             999999            999999  \
# 1988-10-31 00:56:00+00:00             999999            999999
# 1988-10-31 00:56:00+00:00             999999            999999
# 1988-10-31 00:56:00+00:00             999999            999999
# 1988-10-31 00:56:00+00:00             999999            999999
#
#                           QUAL10 (unitless)
# time (UTC)
# 1988-10-31 00:56:00+00:00            999999
# 1988-10-31 00:56:00+00:00            999999
# 1988-10-31 00:56:00+00:00            999999
# 1988-10-31 00:56:00+00:00            999999
# 1988-10-31 00:56:00+00:00            999999
#
# [5 rows x 103 columns]

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
print(df.dtypes)
# Out:
# cruise_name (unitless)                          int64
# EXPOCODE (unitless)                            object
# Ship (unitless)                                object
# STNNBR (unitless)                               int64
# CASTNO (unitless)                               int64
# section (unitless)                             object
# Date (unitless)                                 int64
# Year (unitless)                                 int64
# Month (unitless)                                int64
# Day (unitless)                                  int64
# timeutc (unitless)                              int64
# timecode (unitless)                            object
# longitude (degrees_east)                      float64
# latitude (degrees_north)                      float64
# nav_code (unitless)                            object
# depth_max (meters (m))                        float64
# pres_max (decibars (db))                      float64
# depth_hgt (meters (m))                        float64
# parameters (unitless)                          object
# comments (unitless)                            object
# HOT_summary_file_name (unitless)               object
# ROSETTE (unitless)                              int64
# CTDPRS (decibars)                             float64
# A_CAR (nanograms per liter (ng/L))            float64
# ALKALIN (microeq/kilogram (ueq/kg))           float64
# ATP (nanograms per kilogram (ng/kg))          float64
# B_CAR (nanograms per liter (ng/L))            float64
# BUT_19 (nanograms per liter (ng/L))           float64
# CAROTEN (nanograms per liter (ng/L))          float64
# CHL_Plus (nanograms per liter (ng/L))         float64
# CHLC1_2 (nanograms per liter (ng/L))          float64
# CHLDA_A (nanograms per liter (ng/L))          float64
# CHL_A (micrograms per liter (ug/L))           float64
# CHL_B (nanograms per liter (ng/L))            float64
# CHL_C3 (nanograms per liter (ng/L))           float64
# CHL_C4 (nanograms per liter (ng/L))           float64
# CTDOXY (micromole per kilogram)               float64
# CTDSAL (PSS-78)                               float64
# CTDTMP (degrees celsius)                      float64
# DIADINO (nanograms per liter (ng/L))          float64
# DIC (micromole per kilogram (umol/kg))        float64
# DOC (micromole per kilogram (umol/kg))        float64
# DON (micromole per kilogram (umol/kg))        float64
# DOP (micromole per kilogram (umol/kg))        float64
# DV_CHLA (nanogram per liter (ng/L))           float64
# E_BACT (10^5 per milliliter (10^5/mL))        float64
# FUCO (nanograms per liter (ng/L))             float64
# GTP (nanograms per kilogram (ng/kg))          float64
# H_BACT (10^5 per milliliter (10^5/mL))        float64
# H2O2 (micromole per kilogram (umol/kg))       float64
# HEX_19 (nanograms per liter (ng/L))           float64
# HPLCchl (nanograms per liter (ng/L))          float64
# LLN (nanomole per kilogram (nmol/kg))         float64
# LLP (nanomole per kilogram (nmol/kg))         float64
# LLSi (micromole per kilogram (umol/kg))       float64
# LUTEIN (nanogram per liter (ng/L))            float64
# MV_CHLA (nanogram per liter (ng/L))           float64
# N2O (nanomole per kilogram (nmol/kg))         float64
# NO2 (nanomole per kilogram (nmol/kg))         float64
# NO2_NO3 (micromole per kilogram (umol/kg))    float64
# OXYGEN (micromole per kilogram (umol/kg))     float64
# P_BACT (10^5 per milliliter (10^5/mL))        float64
# P13C (permil vs. VPDB)                        float64
# P15N (permil vs. air-N)                       float64
# PC (micromole per kilogram (umol/kg))         float64
# PERID (nanograms per liter (ng/L))            float64
# PE_pt4u (nanogram per liter (ng/L))           float64
# PE_10u (nanogram per liter (ng/L))            float64
# PE_5u (nanogram per liter (ng/L))             float64
# PH (either TOT25 or NBS25)                    float64
# PHEO (micrograms per liter (ug/L))            float64
# PHSPHT (micromole per kilogram (umol/kg))     float64
# PIC (micromole per kilogram (umol/kg))        float64
# PN (micromole per kilogram (umol/kg))         float64
# PP (nanomole per kilogram (nmol/kg))          float64
# PRASINO (nanogram per liter (ng/L))           float64
# PSi (nanomole per kilogram (nmol/kg))         float64
# REPLICT (unitless)                              int64
# S_BACT (10^5 per milliliter (10^5/mL))        float64
# SALNITY (PSS-78)                              float64
# SIGMA (kilogram per cubic meter (kg/m^3))     float64
# SILCAT (micromole per kilogram (umol/kg))     float64
# SPEC_SI (micromole per kilogram (umol/kg))    float64
# TD700A (microgram per liter (ug/L))           float64
# TD700B (microgram per liter (ug/L))           float64
# TD700C (microgram per liter (ug/L))           float64
# TDN (micromole per kilogram (umol/kg))        float64
# TDP (micromole per kilogram (umol/kg))        float64
# THETA (ITC-90)                                float64
# VIOL (nanogram per liter (ng/L))              float64
# ZEAXAN (nanogram per liter (ng/L))            float64
# num_bottles (unitless)                          int64
# pCO2 (micro atmospheres (uatm))               float64
# QUALT1 (unitless)                               int64
# QUALT2 (unitless)                               int64
# QUALT3 (unitless)                               int64
# QUALT4 (unitless)                               int64
# QUALT5 (unitless)                               int64
# QUALT6 (unitless)                               int64
# QUALT7 (unitless)                               int64
# QUALT8 (unitless)                               int64
# QUALT9 (unitless)                               int64
# QUAL10 (unitless)                               int64
# dtype: object

# %%
pd.set_option('display.max_rows', 10)

# %%
CTDTMP_average = df.groupby(df.index.year)['CTDTMP (degrees celsius)'].mean().reset_index()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5)) 
plt.plot(CTDTMP_average["time (UTC)"],CTDTMP_average["CTDTMP (degrees celsius)"],c='red',marker='.',linestyle='-') 

plt.ylabel('degrees celsius')
plt.legend()
plt.yticks(rotation=90)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (array([34.65, 34.7 , 34.75, 34.8 , 34.85, 34.9 , 34.95, 35.  , 35.05]),
#  [Text(0, 34.650000000000006, '34.65'),
#   Text(0, 34.7, '34.70'),
#   Text(0, 34.75, '34.75'),
#   Text(0, 34.8, '34.80'),
#   Text(0, 34.85, '34.85'),
#   Text(0, 34.900000000000006, '34.90'),
#   Text(0, 34.95, '34.95'),
#   Text(0, 35.0, '35.00'),
#   Text(0, 35.05, '35.05')])
